# %%
import numpy as np
np_arr1 = np.array([1,2,3,4])
np_arr2 = np.array([5,6,7,8])
print(  np.column_stack ((np_arr1, np_arr2))     )
print(  np.row_stack ((np_arr1, np_arr2)))
# np.column_stack
# np.row_stack

# %%
import matplotlib.pyplot as plt
plt.grid()

# %%
import pandas as pd
#df.DataFrame = [fdsfsdfsd]

for rowName, rowData in df.iterrows():
    print(rowName)
    print(rowData["foo"])

# %%
xd = {      'country':'italy' }
'country' in xd
# Out:
# True
